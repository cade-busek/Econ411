# %% [markdown]
# 1. Rerun the last regression where, only including oecd countries in the subset. A list of OECD countries is provided. You will need to find the 3 letter ISO code associated with each country. (Hint: Reimport the dataframe we saved early in the lesson)

# %%
import matplotlib.pyplot as plt
import pandas as pd
hw_data = pd.read_excel("EFWAndRGDP.xls", index_col = [0])
hw_data
# Out:
#                  Year ISO_Code_2   World Bank Region  \
# ISO_Code_3
# AGO        1970-01-01         AO  Sub-Saharan Africa
# AGO        1971-01-01        NaN                 NaN
# AGO        1972-01-01        NaN                 NaN
# AGO        1973-01-01        NaN                 NaN
# AGO        1974-01-01        NaN                 NaN
# ...               ...        ...                 ...
# ZWE        2014-01-01         ZW  Sub-Saharan Africa
# ZWE        2015-01-01         ZW  Sub-Saharan Africa
# ZWE        2016-01-01         ZW  Sub-Saharan Africa
# ZWE        2017-01-01         ZW  Sub-Saharan Africa
# ZWE        2018-01-01         ZW  Sub-Saharan Africa
#
#            World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# ISO_Code_3
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# ...                                                       ...
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                        LM
#
#            Countries   Summary  Size of Government  \
# ISO_Code_3
# AGO           Angola       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# ...              ...       ...                 ...
# ZWE         Zimbabwe  5.999147            6.771807
# ZWE         Zimbabwe  6.449595            6.964753
# ZWE         Zimbabwe  6.121996            5.332597
# ZWE         Zimbabwe  5.599886            4.699843
# ZWE         Zimbabwe  5.876298            5.170946
#
#             Legal System and Property Rights  Sound Money  \
# ISO_Code_3
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# ...                                      ...          ...
# ZWE                                 3.930143     7.664303
# ZWE                                 4.108142     7.859669
# ZWE                                 4.056407     8.086016
# ZWE                                 4.071445     7.983888
# ZWE                                 4.041897     7.312324
#
#             Freedom to Trade Internationally  Regulation  RGDP Per Capita
# ISO_Code_3
# AGO                                      NaN         NaN        2818.0000
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# ...                                      ...         ...              ...
# ZWE                                 6.398692    5.039824        1594.0000
# ZWE                                 6.509231    6.555970        1560.0000
# ZWE                                 6.404937    6.520805        1534.0000
# ZWE                                 4.503965    6.399757        1582.3662
# ZWE                                 6.396649    6.303135        1611.4052
#
# [8085 rows x 12 columns]

# %%
oecd_countries = ["Australia", "Austria", "Belgium", "Canada", "Chile", "Colombia", "Costa Rica",
            "Czech Republic", "Denmark", "Estonia", "Finland", "France", "Germany",
            "Greece", "Hungary", "Iceland", "Ireland", "Israel", "Italy", "Japan", 
            "Latvia", "Lithuania","Luxembourg", "Mexico", "Netherlands", "New Zealand", "Norway",
             "Poland","Portugal", "Slovakia", "Slovenia", "South Korea", "Spain", "Sweden",
             "Switzerland", "Turkey", "United Kingdom", "United States"]

# %%
ahw_data = hw_data[hw_data["Countries"].isin(oecd_countries)]
ahw_data
# Out:
#                  Year ISO_Code_2    World Bank Region  \
# ISO_Code_3
# AUS        1970-01-01         AU  East Asia & Pacific
# AUS        1975-01-01         AU  East Asia & Pacific
# AUS        1980-01-01         AU  East Asia & Pacific
# AUS        1985-01-01         AU  East Asia & Pacific
# AUS        1990-01-01         AU  East Asia & Pacific
# ...               ...        ...                  ...
# USA        2014-01-01         US        North America
# USA        2015-01-01         US        North America
# USA        2016-01-01         US        North America
# USA        2017-01-01         US        North America
# USA        2018-01-01         US        North America
#
#            World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# ISO_Code_3
# AUS                                                       NaN
# AUS                                                       NaN
# AUS                                                       NaN
# AUS                                                       NaN
# AUS                                                         H
# ...                                                       ...
# USA                                                         H
# USA                                                         H
# USA                                                         H
# USA                                                         H
# USA                                                         H
#
#                 Countries   Summary  Size of Government  \
# ISO_Code_3
# AUS             Australia  7.291154            6.863768
# AUS             Australia  7.002204            6.255684
# AUS             Australia  7.316469            6.339449
# AUS             Australia  7.670016            6.259326
# AUS             Australia  7.927001            6.708215
# ...                   ...       ...                 ...
# USA         United States  8.249649            7.239681
# USA         United States  8.309574            7.237673
# USA         United States  8.339536            7.252009
# USA         United States  8.379486            7.354358
# USA         United States  8.279612            7.409095
#
#             Legal System and Property Rights  Sound Money  \
# ISO_Code_3
# AUS                                 7.775615     9.581113
# AUS                                 8.034445     8.346907
# AUS                                 8.037057     9.085686
# AUS                                 8.540345     9.089736
# AUS                                 8.398730     9.018318
# ...                                      ...          ...
# USA                                 7.652463     9.737154
# USA                                 7.745733     9.855788
# USA                                 7.793107     9.814703
# USA                                 7.802657     9.772320
# USA                                 7.646530     9.772494
#
#             Freedom to Trade Internationally  Regulation  RGDP Per Capita
# ISO_Code_3
# AUS                                 5.882101    6.335298       19166.0000
# AUS                                 5.692162    6.761980       20993.0000
# AUS                                 5.841104    7.389934       22972.0000
# AUS                                 6.985368    7.469774       24927.0000
# AUS                                 7.661409    7.750886       27373.0000
# ...                                      ...         ...              ...
# USA                                 7.836022    8.792114       51664.0000
# USA                                 7.810632    8.891698       52591.0000
# USA                                 7.889129    8.952382       53015.0000
# USA                                 7.921225    9.031901       54007.7698
# USA                                 7.783384    8.784245       55334.7394
#
# [900 rows x 12 columns]

# %%
del hw_data['ISO_Code_2']
del hw_data['Year']
del hw_data['World Bank Region']
del hw_data['Countries']
del hw_data['World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)']
hw_data
# Out:
#              Summary  Size of Government  Legal System and Property Rights  \
# ISO_Code_3
# AGO              NaN                 NaN                               NaN
# AGO              NaN                 NaN                               NaN
# AGO              NaN                 NaN                               NaN
# AGO              NaN                 NaN                               NaN
# AGO              NaN                 NaN                               NaN
# ...              ...                 ...                               ...
# ZWE         5.999147            6.771807                          3.930143
# ZWE         6.449595            6.964753                          4.108142
# ZWE         6.121996            5.332597                          4.056407
# ZWE         5.599886            4.699843                          4.071445
# ZWE         5.876298            5.170946                          4.041897
#
#             Sound Money  Freedom to Trade Internationally  Regulation  \
# ISO_Code_3
# AGO                 NaN                               NaN         NaN
# AGO                 NaN                               NaN         NaN
# AGO                 NaN                               NaN         NaN
# AGO                 NaN                               NaN         NaN
# AGO                 NaN                               NaN         NaN
# ...                 ...                               ...         ...
# ZWE            7.664303                          6.398692    5.039824
# ZWE            7.859669                          6.509231    6.555970
# ZWE            8.086016                          6.404937    6.520805
# ZWE            7.983888                          4.503965    6.399757
# ZWE            7.312324                          6.396649    6.303135
#
#             RGDP Per Capita
# ISO_Code_3
# AGO               2818.0000
# AGO                     NaN
# AGO                     NaN
# AGO                     NaN
# AGO                     NaN
# ...                     ...
# ZWE               1594.0000
# ZWE               1560.0000
# ZWE               1534.0000
# ZWE               1582.3662
# ZWE               1611.4052
#
# [8085 rows x 7 columns]

# %%
reg_vars = list(hw_data.keys())
reg_vars
# Out:
# ['Summary',
#  'Size of Government',
#  'Legal System and Property Rights',
#  'Sound Money',
#  'Freedom to Trade Internationally',
#  'Regulation',
#  'RGDP Per Capita']

# %%
y_var = [reg_vars[-1]]
x_vars = reg_vars[:-1]
reg_data = hw_data[reg_vars]
reg_data.corr().round(2)
# Out:
#                                   Summary  Size of Government  \
# Summary                              1.00                0.35
# Size of Government                   0.35                1.00
# Legal System and Property Rights     0.76               -0.08
# Sound Money                          0.83                0.17
# Freedom to Trade Internationally     0.87                0.16
# Regulation                           0.83                0.22
# RGDP Per Capita                      0.57               -0.16
#
#                                   Legal System and Property Rights  \
# Summary                                                       0.76
# Size of Government                                           -0.08
# Legal System and Property Rights                              1.00
# Sound Money                                                   0.52
# Freedom to Trade Internationally                              0.62
# Regulation                                                    0.64
# RGDP Per Capita                                               0.66
#
#                                   Sound Money  \
# Summary                                  0.83
# Size of Government                       0.17
# Legal System and Property Rights         0.52
# Sound Money                              1.00
# Freedom to Trade Internationally         0.69
# Regulation                               0.60
# RGDP Per Capita                          0.46
#
#                                   Freedom to Trade Internationally  \
# Summary                                                       0.87
# Size of Government                                            0.16
# Legal System and Property Rights                              0.62
# Sound Money                                                   0.69
# Freedom to Trade Internationally                              1.00
# Regulation                                                    0.64
# RGDP Per Capita                                               0.51
#
#                                   Regulation  RGDP Per Capita
# Summary                                 0.83             0.57
# Size of Government                      0.22            -0.16
# Legal System and Property Rights        0.64             0.66
# Sound Money                             0.60             0.46
# Freedom to Trade Internationally        0.64             0.51
# Regulation                              1.00             0.53
# RGDP Per Capita                         0.53             1.00

# %%
import statsmodels.api as sm
r_df = reg_data.dropna(axis = 0, how = "any")
y = r_df[y_var]
X = r_df[x_vars]
X["Constant"] = 1
results = sm.OLS(y, X).fit()
r_df["Predictor"] = results.predict()
r_df['Residuals'] = results.resid
results.summary()
# Out:
# /var/folders/7l/h6dgk4zj46v592scp_p1cgwr0000gn/T/ipykernel_9569/45075158.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r_df["Predictor"] = results.predict()
# /var/folders/7l/h6dgk4zj46v592scp_p1cgwr0000gn/T/ipykernel_9569/45075158.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r_df['Residuals'] = results.resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RGDP Per Capita   R-squared:                       0.486
# Model:                            OLS   Adj. R-squared:                  0.485
# Method:                 Least Squares   F-statistic:                     494.6
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):               0.00
# Time:                        16:45:57   Log-Likelihood:                -34081.
# No. Observations:                3145   AIC:                         6.818e+04
# Df Residuals:                    3138   BIC:                         6.822e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Summary                           3444.7542   3987.176      0.864      0.388   -4372.983    1.13e+04
# Size of Government               -3452.3009    835.192     -4.134      0.000   -5089.878   -1814.724
# Legal System and Property Rights  3269.9718    829.247      3.943      0.000    1644.051    4895.893
# Sound Money                        206.1890    825.024      0.250      0.803   -1411.452    1823.831
# Freedom to Trade Internationally   608.9800    804.901      0.757      0.449    -969.205    2187.165
# Regulation                        1437.6438    861.291      1.669      0.095    -251.108    3126.395
# Constant                         -1.644e+04   1637.231    -10.042      0.000   -1.97e+04   -1.32e+04
# ==============================================================================
# Omnibus:                     2952.640   Durbin-Watson:                   0.174
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           189154.035
# Skew:                           4.324   Prob(JB):                         0.00
# Kurtosis:                      39.996   Cond. No.                         331.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# 2. Plot the residuals in a histogram. Explain why the shape of the distribution of these residuals are distinct from the shape of the residuals plotted in the first regressions from this lesson.

# %%
residuals = results.resid
fig, ax = plt.subplots()
ax.hist(residuals, bins=30)
ax.set_xlabel("Residuals")
ax.set_ylabel("Frequency")
ax.set_title("Histogram of Residuals")
plt.show()

# %% [markdown]
# This residual has has more on the right tail but the tail does not go out as causing the data to be more lumped together.

# %% [markdown]
# 3. Plot seperate scatter plots for each variable (x-axis) against the predictor (y-axis). ThenPlot seperate scatter plots for each variable (x-axis) against the predictor (y-axis). Do we observe bias in the resdiuals when controlling for each variable? Why does this matter?

# %%
def plot_residuals(r_df, y_var, x_vars):
    fig, ax = plt.subplots(figsize = (14,10))
    r_df.plot.scatter(x = y_var[0],
                     y = "Predictor", 
                      s = 30, ax = ax)
    plt.xticks(rotation=90)
    plt.show()
    plt.close()

    fig, ax = plt.subplots(figsize = (14,10))
    r_df.plot.scatter(x = y_var,
                     y = "Residuals", 
                      s = 30, ax = ax)
    ax.axhline(0, ls = "--", color = "k")
    plt.xticks(rotation=90)
    plt.show()
    plt.close()

plot_residuals(r_df, y_var, x_vars)

# %%
hw_data = pd.read_excel("EFWAndRGDP.xls", index_col = [0])
hw_data
# Out:
#                  Year ISO_Code_2   World Bank Region  \
# ISO_Code_3
# AGO        1970-01-01         AO  Sub-Saharan Africa
# AGO        1971-01-01        NaN                 NaN
# AGO        1972-01-01        NaN                 NaN
# AGO        1973-01-01        NaN                 NaN
# AGO        1974-01-01        NaN                 NaN
# ...               ...        ...                 ...
# ZWE        2014-01-01         ZW  Sub-Saharan Africa
# ZWE        2015-01-01         ZW  Sub-Saharan Africa
# ZWE        2016-01-01         ZW  Sub-Saharan Africa
# ZWE        2017-01-01         ZW  Sub-Saharan Africa
# ZWE        2018-01-01         ZW  Sub-Saharan Africa
#
#            World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# ISO_Code_3
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# ...                                                       ...
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                        LM
#
#            Countries   Summary  Size of Government  \
# ISO_Code_3
# AGO           Angola       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# ...              ...       ...                 ...
# ZWE         Zimbabwe  5.999147            6.771807
# ZWE         Zimbabwe  6.449595            6.964753
# ZWE         Zimbabwe  6.121996            5.332597
# ZWE         Zimbabwe  5.599886            4.699843
# ZWE         Zimbabwe  5.876298            5.170946
#
#             Legal System and Property Rights  Sound Money  \
# ISO_Code_3
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# ...                                      ...          ...
# ZWE                                 3.930143     7.664303
# ZWE                                 4.108142     7.859669
# ZWE                                 4.056407     8.086016
# ZWE                                 4.071445     7.983888
# ZWE                                 4.041897     7.312324
#
#             Freedom to Trade Internationally  Regulation  RGDP Per Capita
# ISO_Code_3
# AGO                                      NaN         NaN        2818.0000
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# ...                                      ...         ...              ...
# ZWE                                 6.398692    5.039824        1594.0000
# ZWE                                 6.509231    6.555970        1560.0000
# ZWE                                 6.404937    6.520805        1534.0000
# ZWE                                 4.503965    6.399757        1582.3662
# ZWE                                 6.396649    6.303135        1611.4052
#
# [8085 rows x 12 columns]

# %%
predictor = results.predict()
predictor_series = pd.Series(predictor)
ahw_data = ahw_data.reset_index(drop=True)
ahw_data[y_var[0] + 'Predictor'] = predictor_series
ahw_data = ahw_data.rename(columns={y_var[0] + 'Predictor': 'Predictor'})

ahw_data
# Out:
#           Year ISO_Code_2    World Bank Region  \
# 0   1970-01-01         AU  East Asia & Pacific
# 1   1975-01-01         AU  East Asia & Pacific
# 2   1980-01-01         AU  East Asia & Pacific
# 3   1985-01-01         AU  East Asia & Pacific
# 4   1990-01-01         AU  East Asia & Pacific
# ..         ...        ...                  ...
# 895 2014-01-01         US        North America
# 896 2015-01-01         US        North America
# 897 2016-01-01         US        North America
# 898 2017-01-01         US        North America
# 899 2018-01-01         US        North America
#
#     World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                    H
# ..                                                 ...
# 895                                                  H
# 896                                                  H
# 897                                                  H
# 898                                                  H
# 899                                                  H
#
#          Countries   Summary  Size of Government  \
# 0        Australia  7.291154            6.863768
# 1        Australia  7.002204            6.255684
# 2        Australia  7.316469            6.339449
# 3        Australia  7.670016            6.259326
# 4        Australia  7.927001            6.708215
# ..             ...       ...                 ...
# 895  United States  8.249649            7.239681
# 896  United States  8.309574            7.237673
# 897  United States  8.339536            7.252009
# 898  United States  8.379486            7.354358
# 899  United States  8.279612            7.409095
#
#      Legal System and Property Rights  Sound Money  \
# 0                            7.775615     9.581113
# 1                            8.034445     8.346907
# 2                            8.037057     9.085686
# 3                            8.540345     9.089736
# 4                            8.398730     9.018318
# ..                                ...          ...
# 895                          7.652463     9.737154
# 896                          7.745733     9.855788
# 897                          7.793107     9.814703
# 898                          7.802657     9.772320
# 899                          7.646530     9.772494
#
#      Freedom to Trade Internationally  Regulation  RGDP Per Capita  \
# 0                            5.882101    6.335298       19166.0000
# 1                            5.692162    6.761980       20993.0000
# 2                            5.841104    7.389934       22972.0000
# 3                            6.985368    7.469774       24927.0000
# 4                            7.661409    7.750886       27373.0000
# ..                                ...         ...              ...
# 895                          7.836022    8.792114       51664.0000
# 896                          7.810632    8.891698       52591.0000
# 897                          7.889129    8.952382       53015.0000
# 898                          7.921225    9.031901       54007.7698
# 899                          7.783384    8.784245       55334.7394
#
#         Predictor
# 0    -5453.116809
# 1     3307.719203
# 2     4290.751792
# 3     5907.254489
# 4    -1429.994440
# ..            ...
# 895  27792.162134
# 896  27679.495997
# 897  27540.901036
# 898  28222.612896
# 899  27234.547870
#
# [900 rows x 13 columns]

# %% [markdown]
# 4. Plot the observed and predicted values of RGDP Per Capita for each individual country.

# %%
def plot_residuals(data):
    fig, ax = plt.subplots(figsize=(14,10))
    ax.scatter(x=data['RGDP Per Capita'],
               y=data['Predictor'],
               s=50)
    ax.set_title(data['Countries'].iloc[0])
    ax.set_xlabel('RGDP Per Capita')
    ax.set_ylabel('Predictor')
    plt.xticks(rotation=90)
    plt.show()
    plt.close()

for country, data in ahw_data.groupby('Countries'):
    plot_residuals(data)

# %% [markdown]
# 5. Repeat questions 1 through 4 using 2 year lags and differences instead of 5 year lags and differences.

# %%
import pandas as pd
hw_data = pd.read_excel("EFWAndRGDP.xls", index_col = [0])
hw_data

# %%
import numpy as np
years_diff = 5
reg_data = hw_data
reg_data["RGDP Per Capita"] = np['Year'].diff(years_diff) 
reg_data = reg_data.replace([np.inf, -np.inf], np.nan)
reg_data.loc["USA"]

# %%
hw_data[hw_data["Countries"].isin(oecd_countries)]

# %%
del hw_data['ISO_Code_2']
del hw_data['Year']
del hw_data['World Bank Region']
del hw_data['Countries']
del hw_data['World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)']
hw_data
