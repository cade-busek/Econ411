# %% [markdown]
# 1. Rerun the last regression where, only including oecd countries in the subset. A list of OECD countries is provided. You will need to find the 3 letter ISO code associated with each country. (Hint: Reimport the dataframe we saved early in the lesson)

# %%
import matplotlib.pyplot as plt
import pandas as pd
hw_data = pd.read_excel("EFWAndRGDP.xls", index_col = [0])
hw_data
# Out:
#                  Year ISO_Code_2   World Bank Region  \
# ISO_Code_3
# AGO        1970-01-01         AO  Sub-Saharan Africa
# AGO        1971-01-01        NaN                 NaN
# AGO        1972-01-01        NaN                 NaN
# AGO        1973-01-01        NaN                 NaN
# AGO        1974-01-01        NaN                 NaN
# ...               ...        ...                 ...
# ZWE        2014-01-01         ZW  Sub-Saharan Africa
# ZWE        2015-01-01         ZW  Sub-Saharan Africa
# ZWE        2016-01-01         ZW  Sub-Saharan Africa
# ZWE        2017-01-01         ZW  Sub-Saharan Africa
# ZWE        2018-01-01         ZW  Sub-Saharan Africa
#
#            World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# ISO_Code_3
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# ...                                                       ...
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                        LM
#
#            Countries   Summary  Size of Government  \
# ISO_Code_3
# AGO           Angola       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# ...              ...       ...                 ...
# ZWE         Zimbabwe  5.999147            6.771807
# ZWE         Zimbabwe  6.449595            6.964753
# ZWE         Zimbabwe  6.121996            5.332597
# ZWE         Zimbabwe  5.599886            4.699843
# ZWE         Zimbabwe  5.876298            5.170946
#
#             Legal System and Property Rights  Sound Money  \
# ISO_Code_3
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# ...                                      ...          ...
# ZWE                                 3.930143     7.664303
# ZWE                                 4.108142     7.859669
# ZWE                                 4.056407     8.086016
# ZWE                                 4.071445     7.983888
# ZWE                                 4.041897     7.312324
#
#             Freedom to Trade Internationally  Regulation  RGDP Per Capita
# ISO_Code_3
# AGO                                      NaN         NaN        2818.0000
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# ...                                      ...         ...              ...
# ZWE                                 6.398692    5.039824        1594.0000
# ZWE                                 6.509231    6.555970        1560.0000
# ZWE                                 6.404937    6.520805        1534.0000
# ZWE                                 4.503965    6.399757        1582.3662
# ZWE                                 6.396649    6.303135        1611.4052
#
# [8085 rows x 12 columns]

# %%
oecd_countries = ["Australia", "Austria", "Belgium", "Canada", "Chile", "Colombia", "Costa Rica",
            "Czech Republic", "Denmark", "Estonia", "Finland", "France", "Germany",
            "Greece", "Hungary", "Iceland", "Ireland", "Israel", "Italy", "Japan", 
            "Latvia", "Lithuania","Luxembourg", "Mexico", "Netherlands", "New Zealand", "Norway",
             "Poland","Portugal", "Slovakia", "Slovenia", "South Korea", "Spain", "Sweden",
             "Switzerland", "Turkey", "United Kingdom", "United States"]

# %%
hw_data = hw_data[hw_data["Countries"].isin(oecd_countries)]
hw_data
# Out:
#                  Year ISO_Code_2    World Bank Region  \
# ISO_Code_3
# AUS        1970-01-01         AU  East Asia & Pacific
# AUS        1975-01-01         AU  East Asia & Pacific
# AUS        1980-01-01         AU  East Asia & Pacific
# AUS        1985-01-01         AU  East Asia & Pacific
# AUS        1990-01-01         AU  East Asia & Pacific
# ...               ...        ...                  ...
# USA        2014-01-01         US        North America
# USA        2015-01-01         US        North America
# USA        2016-01-01         US        North America
# USA        2017-01-01         US        North America
# USA        2018-01-01         US        North America
#
#            World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# ISO_Code_3
# AUS                                                       NaN
# AUS                                                       NaN
# AUS                                                       NaN
# AUS                                                       NaN
# AUS                                                         H
# ...                                                       ...
# USA                                                         H
# USA                                                         H
# USA                                                         H
# USA                                                         H
# USA                                                         H
#
#                 Countries   Summary  Size of Government  \
# ISO_Code_3
# AUS             Australia  7.291154            6.863768
# AUS             Australia  7.002204            6.255684
# AUS             Australia  7.316469            6.339449
# AUS             Australia  7.670016            6.259326
# AUS             Australia  7.927001            6.708215
# ...                   ...       ...                 ...
# USA         United States  8.249649            7.239681
# USA         United States  8.309574            7.237673
# USA         United States  8.339536            7.252009
# USA         United States  8.379486            7.354358
# USA         United States  8.279612            7.409095
#
#             Legal System and Property Rights  Sound Money  \
# ISO_Code_3
# AUS                                 7.775615     9.581113
# AUS                                 8.034445     8.346907
# AUS                                 8.037057     9.085686
# AUS                                 8.540345     9.089736
# AUS                                 8.398730     9.018318
# ...                                      ...          ...
# USA                                 7.652463     9.737154
# USA                                 7.745733     9.855788
# USA                                 7.793107     9.814703
# USA                                 7.802657     9.772320
# USA                                 7.646530     9.772494
#
#             Freedom to Trade Internationally  Regulation  RGDP Per Capita
# ISO_Code_3
# AUS                                 5.882101    6.335298       19166.0000
# AUS                                 5.692162    6.761980       20993.0000
# AUS                                 5.841104    7.389934       22972.0000
# AUS                                 6.985368    7.469774       24927.0000
# AUS                                 7.661409    7.750886       27373.0000
# ...                                      ...         ...              ...
# USA                                 7.836022    8.792114       51664.0000
# USA                                 7.810632    8.891698       52591.0000
# USA                                 7.889129    8.952382       53015.0000
# USA                                 7.921225    9.031901       54007.7698
# USA                                 7.783384    8.784245       55334.7394
#
# [900 rows x 12 columns]

# %%
del hw_data['ISO_Code_2']
del hw_data['Year']
del hw_data['World Bank Region']
del hw_data['Countries']
del hw_data['World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)']
hw_data
# Out:
#              Summary  Size of Government  Legal System and Property Rights  \
# ISO_Code_3
# AUS         7.291154            6.863768                          7.775615
# AUS         7.002204            6.255684                          8.034445
# AUS         7.316469            6.339449                          8.037057
# AUS         7.670016            6.259326                          8.540345
# AUS         7.927001            6.708215                          8.398730
# ...              ...                 ...                               ...
# USA         8.249649            7.239681                          7.652463
# USA         8.309574            7.237673                          7.745733
# USA         8.339536            7.252009                          7.793107
# USA         8.379486            7.354358                          7.802657
# USA         8.279612            7.409095                          7.646530
#
#             Sound Money  Freedom to Trade Internationally  Regulation  \
# ISO_Code_3
# AUS            9.581113                          5.882101    6.335298
# AUS            8.346907                          5.692162    6.761980
# AUS            9.085686                          5.841104    7.389934
# AUS            9.089736                          6.985368    7.469774
# AUS            9.018318                          7.661409    7.750886
# ...                 ...                               ...         ...
# USA            9.737154                          7.836022    8.792114
# USA            9.855788                          7.810632    8.891698
# USA            9.814703                          7.889129    8.952382
# USA            9.772320                          7.921225    9.031901
# USA            9.772494                          7.783384    8.784245
#
#             RGDP Per Capita
# ISO_Code_3
# AUS              19166.0000
# AUS              20993.0000
# AUS              22972.0000
# AUS              24927.0000
# AUS              27373.0000
# ...                     ...
# USA              51664.0000
# USA              52591.0000
# USA              53015.0000
# USA              54007.7698
# USA              55334.7394
#
# [900 rows x 7 columns]

# %%
reg_vars = list(hw_data.keys())
reg_vars
# Out:
# ['Summary',
#  'Size of Government',
#  'Legal System and Property Rights',
#  'Sound Money',
#  'Freedom to Trade Internationally',
#  'Regulation',
#  'RGDP Per Capita']

# %%
y_var = [reg_vars[-1]]
x_vars = reg_vars[:-1]
reg_data = hw_data[reg_vars]
reg_data.corr().round(2)
# Out:
#                                   Summary  Size of Government  \
# Summary                              1.00                0.26
# Size of Government                   0.26                1.00
# Legal System and Property Rights     0.67               -0.23
# Sound Money                          0.83                0.06
# Freedom to Trade Internationally     0.78                0.02
# Regulation                           0.83                0.17
# RGDP Per Capita                      0.62               -0.14
#
#                                   Legal System and Property Rights  \
# Summary                                                       0.67
# Size of Government                                           -0.23
# Legal System and Property Rights                              1.00
# Sound Money                                                   0.43
# Freedom to Trade Internationally                              0.42
# Regulation                                                    0.60
# RGDP Per Capita                                               0.71
#
#                                   Sound Money  \
# Summary                                  0.83
# Size of Government                       0.06
# Legal System and Property Rights         0.43
# Sound Money                              1.00
# Freedom to Trade Internationally         0.66
# Regulation                               0.59
# RGDP Per Capita                          0.51
#
#                                   Freedom to Trade Internationally  \
# Summary                                                       0.78
# Size of Government                                            0.02
# Legal System and Property Rights                              0.42
# Sound Money                                                   0.66
# Freedom to Trade Internationally                              1.00
# Regulation                                                    0.49
# RGDP Per Capita                                               0.39
#
#                                   Regulation  RGDP Per Capita
# Summary                                 0.83             0.62
# Size of Government                      0.17            -0.14
# Legal System and Property Rights        0.60             0.71
# Sound Money                             0.59             0.51
# Freedom to Trade Internationally        0.49             0.39
# Regulation                              1.00             0.58
# RGDP Per Capita                         0.58             1.00

# %%
import statsmodels.api as sm
r_df = reg_data.dropna(axis = 0, how = "any")
y = r_df[y_var]
X = r_df[x_vars]
X["Constant"] = 1
results = sm.OLS(y, X).fit()
r_df["Predictor"] = results.predict()
r_df['Residuals'] = results.resid
results.summary()
# Out:
# /var/folders/7l/h6dgk4zj46v592scp_p1cgwr0000gn/T/ipykernel_9120/45075158.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r_df["Predictor"] = results.predict()
# /var/folders/7l/h6dgk4zj46v592scp_p1cgwr0000gn/T/ipykernel_9120/45075158.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r_df['Residuals'] = results.resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RGDP Per Capita   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.562
# Method:                 Least Squares   F-statistic:                     186.8
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):          3.69e-152
# Time:                        15:47:18   Log-Likelihood:                -9173.9
# No. Observations:                 869   AIC:                         1.836e+04
# Df Residuals:                     862   BIC:                         1.840e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Summary                          -1.288e+04   1.39e+04     -0.928      0.354   -4.01e+04    1.44e+04
# Size of Government                1722.3650   2762.558      0.623      0.533   -3699.762    7144.492
# Legal System and Property Rights  8675.2852   2797.357      3.101      0.002    3184.857    1.42e+04
# Sound Money                       4859.4943   2828.749      1.718      0.086    -692.548    1.04e+04
# Freedom to Trade Internationally  1745.4452   2759.840      0.632      0.527   -3671.348    7162.239
# Regulation                        4921.0086   2864.796      1.718      0.086    -701.783    1.05e+04
# Constant                         -3.948e+04   3389.480    -11.649      0.000   -4.61e+04   -3.28e+04
# ==============================================================================
# Omnibus:                      205.229   Durbin-Watson:                   0.239
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              583.014
# Skew:                           1.178   Prob(JB):                    2.51e-127
# Kurtosis:                       6.248   Cond. No.                         893.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# 2. Plot the residuals in a histogram. Explain why the shape of the distribution of these residuals are distinct from the shape of the residuals plotted in the first regressions from this lesson.

# %%
residuals = results.resid
fig, ax = plt.subplots()
ax.hist(residuals, bins=30)
ax.set_xlabel("Residuals")
ax.set_ylabel("Frequency")
ax.set_title("Histogram of Residuals")
plt.show()

# %% [markdown]
# This residual has has more on the right tail but the tail does not go out as causing the data to be more lumped together.

# %% [markdown]
# 3. Plot seperate scatter plots for each variable (x-axis) against the predictor (y-axis). ThenPlot seperate scatter plots for each variable (x-axis) against the predictor (y-axis). Do we observe bias in the resdiuals when controlling for each variable? Why does this matter?

# %%
fig, ax = plt.subplots(figsize = (14,10))
r_df.plot.scatter(x = y_var[0],
                 y = "Predictor", 
                  s = 30, ax = ax)
plt.xticks(rotation=90)
plt.show()
plt.close()

fig, ax = plt.subplots(figsize = (14,10))
r_df.plot.scatter(x = y_var,
                 y = "Residuals", 
                  s = 30, ax = ax)
ax.axhline(0, ls = "--", color = "k")
plt.xticks(rotation=90)
plt.show()
plt.close()

# %% [markdown]
# 4. Plot the observed and predicted values of RGDP Per Capita for each individual country.

# %%
r_df
# Out:
#              Summary  Size of Government  Legal System and Property Rights  \
# ISO_Code_3
# AUS         7.291154            6.863768                          7.775615
# AUS         7.002204            6.255684                          8.034445
# AUS         7.316469            6.339449                          8.037057
# AUS         7.670016            6.259326                          8.540345
# AUS         7.927001            6.708215                          8.398730
# ...              ...                 ...                               ...
# USA         8.249649            7.239681                          7.652463
# USA         8.309574            7.237673                          7.745733
# USA         8.339536            7.252009                          7.793107
# USA         8.379486            7.354358                          7.802657
# USA         8.279612            7.409095                          7.646530
#
#             Sound Money  Freedom to Trade Internationally  Regulation  \
# ISO_Code_3
# AUS            9.581113                          5.882101    6.335298
# AUS            8.346907                          5.692162    6.761980
# AUS            9.085686                          5.841104    7.389934
# AUS            9.089736                          6.985368    7.469774
# AUS            9.018318                          7.661409    7.750886
# ...                 ...                               ...         ...
# USA            9.737154                          7.836022    8.792114
# USA            9.855788                          7.810632    8.891698
# USA            9.814703                          7.889129    8.952382
# USA            9.772320                          7.921225    9.031901
# USA            9.772494                          7.783384    8.784245
#
#             RGDP Per Capita     Predictor     Residuals
# ISO_Code_3
# AUS              19166.0000  33904.899251 -14738.899251
# AUS              20993.0000  34594.495145 -13601.495145
# AUS              22972.0000  37654.708730 -14682.708730
# AUS              24927.0000  39739.876301 -14812.876301
# AUS              27373.0000  38191.430002 -10818.430002
# ...                     ...           ...           ...
# USA              51664.0000  37399.664893  14264.335107
# USA              52591.0000  38455.906070  14135.093930
# USA              53015.0000  38741.726718  14273.273282
# USA              54007.7698  38727.773606  15279.996194
# USA              55334.7394  37295.278500  18039.460900
#
# [869 rows x 9 columns]

# %% [markdown]
# 5. Repeat questions 1 through 4 using 2 year lags and differences instead of 5 year lags and differences.

# %%
import pandas as pd
hw_data = pd.read_excel("EFWAndRGDP.xls", index_col = [0])
hw_data
# Out:
#                  Year ISO_Code_2   World Bank Region  \
# ISO_Code_3
# AGO        1970-01-01         AO  Sub-Saharan Africa
# AGO        1971-01-01        NaN                 NaN
# AGO        1972-01-01        NaN                 NaN
# AGO        1973-01-01        NaN                 NaN
# AGO        1974-01-01        NaN                 NaN
# ...               ...        ...                 ...
# ZWE        2014-01-01         ZW  Sub-Saharan Africa
# ZWE        2015-01-01         ZW  Sub-Saharan Africa
# ZWE        2016-01-01         ZW  Sub-Saharan Africa
# ZWE        2017-01-01         ZW  Sub-Saharan Africa
# ZWE        2018-01-01         ZW  Sub-Saharan Africa
#
#            World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# ISO_Code_3
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# AGO                                                       NaN
# ...                                                       ...
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                         L
# ZWE                                                        LM
#
#            Countries   Summary  Size of Government  \
# ISO_Code_3
# AGO           Angola       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# AGO              NaN       NaN                 NaN
# ...              ...       ...                 ...
# ZWE         Zimbabwe  5.999147            6.771807
# ZWE         Zimbabwe  6.449595            6.964753
# ZWE         Zimbabwe  6.121996            5.332597
# ZWE         Zimbabwe  5.599886            4.699843
# ZWE         Zimbabwe  5.876298            5.170946
#
#             Legal System and Property Rights  Sound Money  \
# ISO_Code_3
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# AGO                                      NaN          NaN
# ...                                      ...          ...
# ZWE                                 3.930143     7.664303
# ZWE                                 4.108142     7.859669
# ZWE                                 4.056407     8.086016
# ZWE                                 4.071445     7.983888
# ZWE                                 4.041897     7.312324
#
#             Freedom to Trade Internationally  Regulation  RGDP Per Capita
# ISO_Code_3
# AGO                                      NaN         NaN        2818.0000
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# AGO                                      NaN         NaN              NaN
# ...                                      ...         ...              ...
# ZWE                                 6.398692    5.039824        1594.0000
# ZWE                                 6.509231    6.555970        1560.0000
# ZWE                                 6.404937    6.520805        1534.0000
# ZWE                                 4.503965    6.399757        1582.3662
# ZWE                                 6.396649    6.303135        1611.4052
#
# [8085 rows x 12 columns]

# %%
import numpy as np
years_diff = 5
reg_data = hw_data
reg_data["RGDP Per Capita"] = np['Year'].diff(years_diff) 
reg_data = reg_data.replace([np.inf, -np.inf], np.nan)
reg_data.loc["USA"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/7l/h6dgk4zj46v592scp_p1cgwr0000gn/T/ipykernel_9120/465531659.py in <module>
#       2 years_diff = 5
#       3 reg_data = hw_data
# ----> 4 reg_data["RGDP Per Capita"] = np['Year'].diff(years_diff)
#       5 reg_data = reg_data.replace([np.inf, -np.inf], np.nan)
#       6 reg_data.loc["USA"]
#
# TypeError: 'module' object is not subscriptable

# %%
hw_data[hw_data["Countries"].isin(oecd_countries)]

# %%
del hw_data['ISO_Code_2']
del hw_data['Year']
del hw_data['World Bank Region']
del hw_data['Countries']
del hw_data['World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)']
hw_data
