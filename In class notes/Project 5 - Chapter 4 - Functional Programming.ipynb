# %% [markdown]
# # Chapter 4: Functional Programming: Rediment Statistics and Analytics
#
# Often we are performing statistical operations over a large dataset. It can be difficult to understand the meaning conveyed by these measures. Learning to program presents an opportunity to better understand how functions work. In this chapter we will create some basic statistical functions and compare their output to the functions built into python. By creating the function, you will understand the meaning of summation signs. Computing these statistics by hand would be a laborious process and expensive in terms of time. Once a function is constructed, it can be employed to calculate statistics in a fraction of the time.
#
#  ## Building a Function\n,
#
# New Concepts: return obj(from function)
#
# Description: So far, we have built programs on the fly. For purposes of pedagogy, this is fine. As you develop your skills, you want to form good practices. This includes the building of functions for repeated use as well as the building of classes. This chapter we will concentrate on functions. Build all of your functions in the same file, _statsFunctions.py_.\n
#
# In python, functions take the form:

# %%
#def function_name(object1, object2, . . ., objectn):
 #   <operations>

# %% [markdown]
# ### Total
#
# If the function allows, you will pass an onject by calling it in the parentheses that follow the function name. The first function that we build will be the total() function. We define the function algebraically as the sum of all values in a list of length j:
#
# $\sum_{i=0}^{n-1} x_{i}$
#
# Since lists indicies start with integer 0, we will write our functions as starting with _i=0_ and process elements to the index of the value _n-1_.
# Since the range function in Python automatically counts to one less than the value identified, the for-loop used will take the form:

# %%
n = 0 
total = 0
values = [i for i in range(100)]

print('totals\t', 'value')
for value in values:
    total += value
    print(total,"\t", value)
    
print('final total:', total)
# Out:
# totals	 value
# 0 	 0
# 1 	 1
# 3 	 2
# 6 	 3
# 10 	 4
# 15 	 5
# 21 	 6
# 28 	 7
# 36 	 8
# 45 	 9
# 55 	 10
# 66 	 11
# 78 	 12
# 91 	 13
# 105 	 14
# 120 	 15
# 136 	 16
# 153 	 17
# 171 	 18
# 190 	 19
# 210 	 20
# 231 	 21
# 253 	 22
# 276 	 23
# 300 	 24
# 325 	 25
# 351 	 26
# 378 	 27
# 406 	 28
# 435 	 29
# 465 	 30
# 496 	 31
# 528 	 32
# 561 	 33
# 595 	 34
# 630 	 35
# 666 	 36
# 703 	 37
# 741 	 38
# 780 	 39
# 820 	 40
# 861 	 41
# 903 	 42
# 946 	 43
# 990 	 44
# 1035 	 45
# 1081 	 46
# 1128 	 47
# 1176 	 48
# 1225 	 49
# 1275 	 50
# 1326 	 51
# 1378 	 52
# 1431 	 53
# 1485 	 54
# 1540 	 55
# 1596 	 56
# 1653 	 57
# 1711 	 58
# 1770 	 59
# 1830 	 60
# 1891 	 61
# 1953 	 62
# 2016 	 63
# 2080 	 64
# 2145 	 65
# 2211 	 66
# 2278 	 67
# 2346 	 68
# 2415 	 69
# 2485 	 70
# 2556 	 71
# 2628 	 72
# 2701 	 73
# 2775 	 74
# 2850 	 75
# 2926 	 76
# 3003 	 77
# 3081 	 78
# 3160 	 79
# 3240 	 80
# 3321 	 81
# 3403 	 82
# 3486 	 83
# 3570 	 84
# 3655 	 85
# 3741 	 86
# 3828 	 87
# ...

# %%
#copying and pasting is a bad idea, you should not need to use old code again
print('totals\t', 'value')
total = 0
values = [i for i in range(0,1000,2)]
for value in values:
    total += value
    print(total,"\t", value)
# Out:
# totals	 value
# 0 	 0
# 2 	 2
# 6 	 4
# 12 	 6
# 20 	 8
# 30 	 10
# 42 	 12
# 56 	 14
# 72 	 16
# 90 	 18
# 110 	 20
# 132 	 22
# 156 	 24
# 182 	 26
# 210 	 28
# 240 	 30
# 272 	 32
# 306 	 34
# 342 	 36
# 380 	 38
# 420 	 40
# 462 	 42
# 506 	 44
# 552 	 46
# 600 	 48
# 650 	 50
# 702 	 52
# 756 	 54
# 812 	 56
# 870 	 58
# 930 	 60
# 992 	 62
# 1056 	 64
# 1122 	 66
# 1190 	 68
# 1260 	 70
# 1332 	 72
# 1406 	 74
# 1482 	 76
# 1560 	 78
# 1640 	 80
# 1722 	 82
# 1806 	 84
# 1892 	 86
# 1980 	 88
# 2070 	 90
# 2162 	 92
# 2256 	 94
# 2352 	 96
# 2450 	 98
# 2550 	 100
# 2652 	 102
# 2756 	 104
# 2862 	 106
# 2970 	 108
# 3080 	 110
# 3192 	 112
# 3306 	 114
# 3422 	 116
# 3540 	 118
# 3660 	 120
# 3782 	 122
# 3906 	 124
# 4032 	 126
# 4160 	 128
# 4290 	 130
# 4422 	 132
# 4556 	 134
# 4692 	 136
# 4830 	 138
# 4970 	 140
# 5112 	 142
# 5256 	 144
# 5402 	 146
# 5550 	 148
# 5700 	 150
# 5852 	 152
# 6006 	 154
# 6162 	 156
# 6320 	 158
# 6480 	 160
# 6642 	 162
# 6806 	 164
# ...

# %%
def total(lst):
    total_ = 0
    # in original, I used the index of the list
    # ... 
    # n = len(lst)
    # for i in range(n)
    for val in lst:
        total_ += val
    return total_
total(values)
# Out:
# 249500

# %%
total([i for i in range(-1000, 10000, 53)])
# Out:
# 932984

# %%
import random
x1 = [3,6,9,12,15,18,21,24,27,30]
x2 = [random.randint(0,100) for i in range(10)]
total(x1), total(x2)
# Out:
# (165, 620)

# %% [markdown]
# ### Mean
#
# Let $X_1, X_2, ..., X_n$ represent $n$ values from a random variable. For a given dataset, useful descriptive statistics of central tendency include mean, median, and mode, which we built as functions in a previous chapter.
#
# We define the mean of a set of numbers:
# $ \bar{X} = \frac{\sum_{i=0}^{n-1} X_{i}} {n}$

# %%
def mean(lst):
    n = len(lst)
    mean_ = total(lst) /n
    return mean_
mean(x1), mean(x2)
# Out:
# (16.5, 62.0)

# %% [markdown]
# ### Now lets build the rest of the summary statistical functions
#     #1. median
#     #2. mode
#     #3. variance
#     #4. standard deviation
#     #5. standard error
#     #6. covariance
#     #7. correlation

# %%
def median(lst):
    n = len(lst)
    lst = sorted(lst)
    
    #two cases
    #1. list of odd length
    # i % j checks for remainder upon dividing i by j
    if n % 2 !=0:
        middle_index = int((n-1)/2)
        median_ = lst[middle_index]

    #2. list of odd length
    else:
        upper_middle_index = int(n/2)
        lower_middle_index = upper_middle_index - 1
        #pass sloce with two middel values to mean()
        median_ = mean(lst[lower_middle_index: upper_middle_index + 1])
    return median_

median(x1), median(x2)
# Out:
# (16.5, 71.5)

# %%
# transform x1 to be of odd length by removing the last index
# this is to test the first case in the median() function
median(x1[:-1])
# Out:
# 15

# %%
sorted(x2)
# Out:
# [2, 37, 55, 60, 71, 72, 76, 77, 77, 93]

# %% [markdown]
# ### Mode

# %%
def mode(lst):
    
    # creates entries for each value with 0
    count_dct = {}
    
    for key in lst:
        count_dct[key] = 0
    # add up each occurence
    for key in lst:
        count_dct[key] += 1
        
   # calculate max_count up front
    max_count = max(count_dct.values())
    #now we can compare each count to the max count
    mode_ = []
    for key, count in count_dct.items():
        if count == max_count:
           mode_.append(key)
    return mode_

    
lst = [1,1,1,1,1,1,2,3,4,5,5,5,5,5,5,100000]
mode(lst)
# Out:
# [1, 5]

# %% [markdown]
# ### Variance
#
#
# $$ \sigma^2 = \frac{\sum_{i=1}^n (X_i - \bar{X})^2}{n}$$
#
# When we are dealing with a sample, which is a subset of a population of observations, then we divide by $n - 1$, the **Degrees of Freedom**, to the unbias the calculation.
#
# $$DoF = n - 1$$
#
# $$ S^2 = \frac{\sum_{i=1}^n (X_i - \bar{X})^2}{n-1}$$

# %%
def variance(lst, sample = True):
    list_mean = mean(lst)
    n = len(lst)
    DoF = n-1
    sum_sq_diff = 0
    
    for val in lst:
        diff = val - list_mean
        sum_sq_diff += (val - list_mean)**2
#        print(val,list_mean**2, sum_sq_diff)
    if sample == False:
        variance_ = sum_sq_diff/n
    else:
        variance_ = sum_sq_diff/DoF
    return variance_
            
variance(x1, sample = True), variance(x1, sample = False)
# Out:
# (82.5, 74.25)

# %%
variance(x2, sample = True), variance(x2, sample = False)
# Out:
# (674.0, 606.6)

# %% [markdown]
# $ SD = \sqrt(S^2)$

# %%
def SD(lst, sample = True):
    SD_ = variance(lst, sample)**(1/2)
    return SD_
SD(x1, sample = True), SD(x1, sample = False)
# Out:
# (9.082951062292475, 8.616843969807043)

# %%
SD(x2, sample = True), SD(x2, sample = False)
# Out:
# (25.96150997149434, 24.62925090212855)

# %% [markdown]
# ### Standard Error

# %%
def STE(lst, sample = True):
    n = len(lst)
    se = SD(lst, sample) / n ** (1/2)
    
    return se

# this is a reference to the mean of the data you have drawn from

# %%
SD(x1, sample = True), STE(x1, sample = True)
# Out:
# (9.082951062292475, 2.872281323269014)

# %%
SD(x2, sample = True), STE(x2, sample = True)
# Out:
# (25.96150997149434, 8.209750300709517)

# %% [markdown]
# ### Covariance
#
# To calculate covariance, we multiply the sum of the product of the difference between the observed value and the mean of each list for value _i = 1_ through _n = number of observations_:
#
# $cov_{pop}(x,y) = \frac{\sum_{i=0}^{n-1} (x_{i} - x_{mean})(y_{i} - y_{mean})} {n-1}$
#
# We pass two lists through covariance() function. As with the _variance()_ and _SD()_ functions, we can take the sample_covariance.
#
# $cov_{sample}(x,y) = \frac{\sum_{i=0}^{n-1} (x_{i} - x_{mean})(y_{i} - y_{mean})} {n-1}$
#
#
#
# used to compare to list through correlation

# %%
def covariance(lst1, lst2, sample = True):
    mean1 = mean(lst1)
    mean2 = mean(lst2)
    
    cov = 0
    n1 = len(lst1)
    n2 = len(lst2)
    if n1 == n2:
        n = n1
        # sum the product of the differences
        for i in range(n):
            cov += (lst1[i]- mean1)*(lst2[i]- mean2)
        if sample == False:
            cov = cov/n
        else:
            cov = cov/(n-1)
            
        return cov
    else: 
        print("List lengths are not equal")
        print("List1:", n1)
        print('List2:', n2)
covariance(x1, x2, sample = True)
# Out:
# -4.333333333333333

# %%
covariance(x1[:-1], x2)
# Out:
# List lengths are not equal
# List1: 9
# List2: 10

# %% [markdown]
# # Corrolation
# $corr_{pop}(x,y) = \frac{cov_{pop}(x,y)} {\sigma_x \sigma_y}$

# %%
def correlation(lst1,lst2):
    cov = covariance(lst1, lst2)
    SD1 = SD(lst1)
    SD2 = SD(lst2)
    corr = cov/(SD1 * SD2)
    
    return corr
correlation(x1, x2)
# Out:
# -0.018376600542312833

# %%
x3 = [x * -.5 for x in x1]
correlation(x1, x3)
# Out:
# -1.0

# %% [markdown]
# ### Skew
#
# $skew_{pop}(x,y) = \frac{sum_{i=0}^{n-1}{(x_{i} - x_{mean})^3}}{n\sigma^3}$
#
# $skew_{sample}(x,y) = \frac{sum_{i=0}^{n-1}{(x_{i} - x_{mean})^3}}{(n-1)(n-2)\sigma^3}$

# %%
# skewness measures the lean of the distribution
def skewness(lst, sample = True):
    mean_ = mean(lst)
    SD_ = SD(lst, sample)
    skew = 0
    n = len(lst)
    for val in lst:
        skew += (val - mean_) ** 3
    skew = skew/(n*SD_**3) if not sample else n * skew/(
        (n-1)*(n-2)* SD_**3)
    # for population
    return skew
skewness(x1)
# Out:
# 0.0

# %%
skewness(x2)
# Out:
# -1.5157396565501118

# %% [markdown]
# ### Kurtosis
#
# $kurt_{pop}(x,y) = \frac{\sum_{i=0}^{n-1}(x_{i} - x_{mean})^4}{n\sigma^4}$
#
# $kurt_{sample} = \frac{n(n+1)\sum_{i=0}^{n-1} (x_{i} - x_{mean})^4} {(n-1)(n-2)(n-3)\sigma^4} - \frac{3(n-1)^2}{(n-2)(n-3)}$

# %%
# kurtosis measures how fat the tails are of a dataset
def kurtosis(lst, sample = True):
    mean_= mean(lst)
    kurt = 0
    SD_ = SD(lst, sample)
    n = len(lst)
    for val in lst:
        kurt += (val - mean_)**4
    kurt = kurt/(n*SD_**4) if sample == False else n * (n+1)*kurt/ \
        ((n-1)*(n-2)*(n-3)*(SD_**4))-(3*(n-1)**2)/((n-2)*(n-3))
    
    return kurt

kurtosis(x1, sample = False)
# Out:
# 1.7757575757575759

# %%
kurtosis(x2, sample = False)
# Out:
# 3.9223422014940827

# %% [markdown]
# # Gather Statistics

# %%
import pandas as pd

def gather_statistics(df, sample = False, round_dig = 3):
    dct = {key:{} for key in df}
    for key, val in df.items():
        val.dropna(inplace = True)
        dct[key]['mean']= round(mean(val),round_dig)
        dct[key]['median']= round(median(val),round_dig)
        dct[key]['variance']= round(variance(val),round_dig)
        dct[key]['S.D.']= round(SD(val, sample),round_dig)
        dct[key]['Skewness']= round(skewness(val, sample),round_dig)
        dct[key]['Kurtosis']= round(kurtosis(val, sample),round_dig)
    stats_df = pd.DataFrame(dct)
    print(stats_df)    
        
    
data = pd.DataFrame([x1,x2], index = ['List1', 'List2']).T
gather_statistics(data, sample = False, round_dig = 2)
# Out:
#           List1   List2
# mean      16.50   62.00
# median    16.50   71.50
# variance  82.50  674.00
# S.D.       8.62   24.63
# Skewness   0.00   -1.28
# Kurtosis   1.78    3.92

# %% [markdown]
# ## Fraser Economic Freedom of the World

# %%
filename = "efotw-2022-master-index-data-for-researchers-iso.xlsx"
data = pd.read_excel(filename, header = [4],
                    index_col = [3,1])
data
# Out:
#                  Unnamed: 0 ISO Code 2      Countries  \
# ISO Code 3 Year
# ALB        2020         NaN         AL        Albania
# DZA        2020         NaN         DZ        Algeria
# AGO        2020         NaN         AO         Angola
# ARG        2020         NaN         AR      Argentina
# ARM        2020         NaN         AM        Armenia
# ...                     ...        ...            ...
# VEN        1970         NaN         VE  Venezuela, RB
# VNM        1970         NaN         VN        Vietnam
# YEM        1970         NaN         YE    Yemen, Rep.
# ZMB        1970         NaN         ZM         Zambia
# ZWE        1970         NaN         ZW       Zimbabwe
#
#                  Economic Freedom Summary Index   Rank  Quartile  \
# ISO Code 3 Year
# ALB        2020                            7.64   26.0       1.0
# DZA        2020                            5.12  157.0       4.0
# AGO        2020                            5.91  138.0       4.0
# ...

# %%
data.__dict__
# Out:
# {'_is_copy': None,
#  '_mgr': BlockManager
#  Items: Index(['Unnamed: 0', 'ISO Code 2', 'Countries',
#         'Economic Freedom Summary Index', 'Rank', 'Quartile',
#         '1A Government Consumption', 'data', '1B  Transfers and subsidies',
#         'data.1',
#         ...
#         'Unnamed: 101', 'Unnamed: 102', 'Unnamed: 103', 'Unnamed: 104',
#         'Unnamed: 105', 'Unnamed: 106', 'Unnamed: 107', 'Unnamed: 108',
#         'Unnamed: 109', 'Unnamed: 110'],
#        dtype='object', length=109)
#  Axis 1: MultiIndex([('ALB', 2020),
#              ('DZA', 2020),
#              ('AGO', 2020),
#              ('ARG', 2020),
#              ('ARM', 2020),
#              ('AUS', 2020),
#              ('AUT', 2020),
#              ('AZE', 2020),
#              ('BHS', 2020),
#              ('BHR', 2020),
#              ...
#              ('UKR', 1970),
#              ('ARE', 1970),
#              ('GBR', 1970),
#              ('USA', 1970),
#              ('URY', 1970),
# ...

# %%
file = pd.ExcelFile(filename)

file.sheet_names  # see all sheet names

for sheet_name in file.sheet_names:
    print(sheet_name)
    print(pd.read_excel(filename, header =[4],
                    index_col = [1,3],
         sheet_name = sheet_name))
# Out:
# EFW Data 2022 Report
#                  Unnamed: 0 ISO Code 2      Countries  \
# Year ISO Code 3
# 2020 ALB                NaN         AL        Albania
#      DZA                NaN         DZ        Algeria
#      AGO                NaN         AO         Angola
#      ARG                NaN         AR      Argentina
#      ARM                NaN         AM        Armenia
# ...                     ...        ...            ...
# 1970 VEN                NaN         VE  Venezuela, RB
#      VNM                NaN         VN        Vietnam
#      YEM                NaN         YE    Yemen, Rep.
#      ZMB                NaN         ZM         Zambia
#      ZWE                NaN         ZW       Zimbabwe
#
#                  Economic Freedom Summary Index   Rank  Quartile  \
# Year ISO Code 3
# 2020 ALB                                   7.64   26.0       1.0
#      DZA                                   5.12  157.0       4.0
# ...

# %%
dir(data)
# Out:
# ['Countries',
#  'Quartile',
#  'Rank',
#  'Region',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
# draw the target sheet_name from the list of sheet_names
sheet_name = file.sheet_names[1]
data = pd.read_excel(filename,
                    sheet_name = sheet_name,
                    index_col = [2,0])

rename = {"Panel Data Summary Index": "Summary",
         "Area 1": "Size of Government",
         "Area 2": "Legal System and Property Rights",
         "Area 3": "Sound Money",
         "Area 4": "Freedom to Trade Internationally", 
         "Area 5": " Regulation"}
data.rename(columns = rename, inplace = True)

data
# Out:
#                 ISO_Code_2              World Bank Region  \
# ISO_Code_3 Year
# ALB        2020         AL          Europe & Central Asia
# DZA        2020         DZ     Middle East & North Africa
# AGO        2020         AO             Sub-Saharan Africa
# ARG        2020         AR  Latin America & the Caribbean
# ARM        2020         AM          Europe & Central Asia
# ...                    ...                            ...
# VEN        1970         VE  Latin America & the Caribbean
# VNM        1970         VN            East Asia & Pacific
# YEM        1970         YE     Middle East & North Africa
# ZMB        1970         ZM             Sub-Saharan Africa
# ZWE        1970         ZW             Sub-Saharan Africa
#
#                 World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# ISO_Code_3 Year
# ALB        2020                                                 UM
# ...

# %% [markdown]
# ### Segue on boolean series, calling subsets of data

# %%
income_levels = data.keys()[2]
# access the unique c
data[income_levels].unique()
# Out:
# array(['UM', 'LM', 'H', 'L', nan, '..'], dtype=object)

# %%
high_income_bool = data[income_levels] =="H" 
data[high_income_bool]
# Out:
#                 ISO_Code_2              World Bank Region  \
# ISO_Code_3 Year
# AUS        2020         AU            East Asia & Pacific
# AUT        2020         AT          Europe & Central Asia
# BHS        2020         BS  Latin America & the Caribbean
# BHR        2020         BH     Middle East & North Africa
# BRB        2020         BB  Latin America & the Caribbean
# ...                    ...                            ...
# SWE        1990         SE          Europe & Central Asia
# CHE        1990         CH          Europe & Central Asia
# ARE        1990         AE     Middle East & North Africa
# GBR        1990         GB          Europe & Central Asia
# USA        1990         US                  North America
#
#                 World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# ISO_Code_3 Year
# AUS        2020                                                  H
# ...

# %%
um_income_bool = data[income_levels] =="UM" 
data[um_income_bool]
# Out:
#                 ISO_Code_2              World Bank Region  \
# ISO_Code_3 Year
# ALB        2020         AL          Europe & Central Asia
# ARG        2020         AR  Latin America & the Caribbean
# ARM        2020         AM          Europe & Central Asia
# AZE        2020         AZ          Europe & Central Asia
# BLR        2020         BY          Europe & Central Asia
# ...                    ...                            ...
# ZAF        1990         ZA             Sub-Saharan Africa
# SUR        1990         SR  Latin America & the Caribbean
# TTO        1990         TT  Latin America & the Caribbean
# URY        1990         UY  Latin America & the Caribbean
# VEN        1990         VE  Latin America & the Caribbean
#
#                 World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# ISO_Code_3 Year
# ALB        2020                                                 UM
# ...

# %%
# include rows if the  income_levels column is either "H" or "UM"
# | is or
data[um_income_bool | high_income_bool]
# Out:
#                 ISO_Code_2              World Bank Region  \
# ISO_Code_3 Year
# ALB        2020         AL          Europe & Central Asia
# ARG        2020         AR  Latin America & the Caribbean
# ARM        2020         AM          Europe & Central Asia
# AUS        2020         AU            East Asia & Pacific
# AUT        2020         AT          Europe & Central Asia
# ...                    ...                            ...
# ARE        1990         AE     Middle East & North Africa
# GBR        1990         GB          Europe & Central Asia
# USA        1990         US                  North America
# URY        1990         UY  Latin America & the Caribbean
# VEN        1990         VE  Latin America & the Caribbean
#
#                 World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# ISO_Code_3 Year
# ALB        2020                                                 UM
# ...

# %%
# choose only the subset of columns that interest you
data = data[data.keys()[4:-1]]
data
# Out:
#                   Summary  Size of Government  \
# ISO_Code_3 Year
# ALB        2020  7.640000            7.817077
# DZA        2020  5.120000            4.409943
# AGO        2020  5.910000            8.133385
# ARG        2020  4.870000            6.483768
# ARM        2020  7.840000            7.975292
# ...                   ...                 ...
# VEN        1970  7.242943            8.349529
# VNM        1970       NaN                 NaN
# YEM        1970       NaN                 NaN
# ZMB        1970  4.498763            5.374545
# ZWE        1970       NaN                 NaN
#
#                  Legal System and Property Rights  Sound Money  \
# ISO_Code_3 Year
# ALB        2020                          5.260351     9.788269
# DZA        2020                          4.131760     7.630287
# AGO        2020                          3.705161     6.087996
# ARG        2020                          4.796454     4.516018
# ...

# %%
data.dropna() # same as . . . (axis = 0, how = 'any')
# Out:
#                   Summary  Size of Government  \
# ISO_Code_3 Year
# ALB        2020  7.640000            7.817077
# DZA        2020  5.120000            4.409943
# AGO        2020  5.910000            8.133385
# ARG        2020  4.870000            6.483768
# ARM        2020  7.840000            7.975292
# ...                   ...                 ...
# TUN        1970  5.538385            4.946963
# TUR        1970  4.277887            5.183333
# GBR        1970  6.035320            4.622300
# USA        1970  7.615181            5.341231
# VEN        1970  7.242943            8.349529
#
#                  Legal System and Property Rights  Sound Money  \
# ISO_Code_3 Year
# ALB        2020                          5.260351     9.788269
# DZA        2020                          4.131760     7.630287
# AGO        2020                          3.705161     6.087996
# ARG        2020                          4.796454     4.516018
# ...

# %%
data.dropna(axis = 1, how = 'any')
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
data_for_stats = data.dropna(how = 'any')
data
# Out:
#                   Summary  Size of Government  \
# ISO_Code_3 Year
# ALB        2020  7.640000            7.817077
# DZA        2020  5.120000            4.409943
# AGO        2020  5.910000            8.133385
# ARG        2020  4.870000            6.483768
# ARM        2020  7.840000            7.975292
# ...                   ...                 ...
# VEN        1970  7.242943            8.349529
# VNM        1970       NaN                 NaN
# YEM        1970       NaN                 NaN
# ZMB        1970  4.498763            5.374545
# ZWE        1970       NaN                 NaN
#
#                  Legal System and Property Rights  Sound Money  \
# ISO_Code_3 Year
# ALB        2020                          5.260351     9.788269
# DZA        2020                          4.131760     7.630287
# AGO        2020                          3.705161     6.087996
# ARG        2020                          4.796454     4.516018
# ...

# %%
stats_DF = gather_statistics(data_for_stats, sample = False)
stats_DF
# Out:
#           Summary  Size of Government  Legal System and Property Rights  \
# mean        6.635               6.609                             5.282
# median      6.763               6.650                             5.098
# variance    1.274               1.466                             2.816
# S.D.        1.128               1.211                             1.678
# Skewness   -0.597              -0.136                             0.350
# Kurtosis    3.176               2.599                             2.404
#
#           Sound Money  Freedom to Trade Internationally   Regulation
# mean            7.813                             6.757        6.733
# median          8.154                             7.013        6.867
# variance        3.110                             2.874        1.448
# S.D.            1.763                             1.695        1.203
# Skewness       -1.312                            -0.984       -0.551
# ...

# %%
cov_DF = data_for_stats.cov().round(2)
cov_DF
# Out:
#                                   Summary  Size of Government  \
# Summary                              1.27                0.42
# Size of Government                   0.42                1.47
# Legal System and Property Rights     1.45               -0.25
# Sound Money                          1.67                0.30
# Freedom to Trade Internationally     1.68                0.31
#  Regulation                          1.13                0.25
#
#                                   Legal System and Property Rights  \
# Summary                                                       1.45
# Size of Government                                           -0.25
# Legal System and Property Rights                              2.82
# Sound Money                                                   1.55
# Freedom to Trade Internationally                              1.80
#  Regulation                                                   1.31
#
#                                   Sound Money  \
# ...

# %%
corr_DF = data_for_stats.cov().round(2)
corr_DF
# Out:
#                                   Summary  Size of Government  \
# Summary                              1.27                0.42
# Size of Government                   0.42                1.47
# Legal System and Property Rights     1.45               -0.25
# Sound Money                          1.67                0.30
# Freedom to Trade Internationally     1.68                0.31
#  Regulation                          1.13                0.25
#
#                                   Legal System and Property Rights  \
# Summary                                                       1.45
# Size of Government                                           -0.25
# Legal System and Property Rights                              2.82
# Sound Money                                                   1.55
# Freedom to Trade Internationally                              1.80
#  Regulation                                                   1.31
#
#                                   Sound Money  \
# ...

# %%
# alphabetize columns
data_for_stats.corr().round(2).sort_index(axis = 1).sort_index(axis = 0)
# Out:
#                                    Regulation  \
#  Regulation                              1.00
# Freedom to Trade Internationally         0.65
# Legal System and Property Rights         0.65
# Size of Government                       0.17
# Sound Money                              0.60
# Summary                                  0.83
#
#                                   Freedom to Trade Internationally  \
#  Regulation                                                   0.65
# Freedom to Trade Internationally                              1.00
# Legal System and Property Rights                              0.63
# Size of Government                                            0.15
# Sound Money                                                   0.69
# Summary                                                       0.88
#
#                                   Legal System and Property Rights  \
#  Regulation                                                   0.65
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
def corr_matrix_heatmap(data, dim = 20, pp = None):
    fig, ax = plt.subplots(figsize =(dim,dim))
    im = ax.imshow(data, norm = plt.cm.colors.Normalize(-1,1), cmap = 'seismic')
    labels = data.keys()
    num_vars = len(labels)
    tick_labels = [label.replace(' ','\n') for label in labels]
    tick_font_size = 120 / num_vars
    val_font_size = 200 / num_vars
    plt.rcParams.update({'font.size': tick_font_size})
    x_ticks = np.arange(num_vars)
    plt.xticks(x_ticks, tick_labels, fontsize = tick_font_size,  rotation = 90)
    y_ticks = np.arange(num_vars)
    plt.yticks(y_ticks, tick_labels, fontsize = tick_font_size)
    # put all of the options chosen above to use and create the correlation figure
    for i in range(len(labels)):
        for j in range (len(labels)):
            text = ax.text(i,j, str(round(data.values[i][j],2)),
                      fontsize = val_font_size, ha = 'center',
                      va = 'center', color = 'w')
        
    title_font = {'fontname':"Times New Roman"}
    plt.title('Correlation', fontsize = 50, ** title_font)
        #print(i, labels[i], j, labels[j], data.values[i,[j]])
    cbar = fig.colorbar(im)
    plt.show()
    if pp != None:
            pp.save(fig, bbox_inches = 'tight')
    plt.close()
    
import os

# create a folder on the fly to save jpeg files to figures
folder = "Project 5 Plots"
try:
    os.mkdir('folder')
except:
    print(folder,'already exists')


pp = PdfPages(folder + "/ Economic Freedom Plots.pdf")  

corr_matrix_heatmap(data.corr())
# Out:
# Project 5 Plots already exists
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /var/folders/7l/h6dgk4zj46v592scp_p1cgwr0000gn/T/ipykernel_38567/3239809227.py in <module>
#      41
#      42
# ---> 43 pp = PdfPages(folder + "/ Economic Freedom Plots.pdf")
#      44
#      45 corr_matrix_heatmap(data.corr())
#
# ~/Downloads/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, keep_empty, metadata)
#    2689             and 'CreationDate'. They can be removed by setting them to `None`.
#    2690         """
# -> 2691         self._file = PdfFile(filename, metadata=metadata)
#    2692         self.keep_empty = keep_empty
#    2693
#
# ~/Downloads/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, metadata)
#     652         self.original_file_like = None
# ...

# %% [markdown]
# ### Building scatter plots with time as horizontal axis

# %%
mean_data = data.groupby('Year').mean()
mean_data
# Out:
#        Summary  Size of Government  Legal System and Property Rights  \
# Year
# 1970  5.699777            6.115453                          4.828106
# 1975  5.330897            5.638449                          4.704443
# 1980  5.358043            5.474844                          4.790720
# 1985  5.423119            5.477523                          4.872785
# 1990  5.716292            6.061804                          4.964320
# 1995  6.163039            6.497296                          5.199571
# 2000  6.592760            6.628378                          5.231726
# 2001  6.599041            6.668608                          5.196628
# 2002  6.663490            6.662246                          5.185988
# 2003  6.681009            6.672367                          5.166744
# 2004  6.710922            6.725984                          5.166447
# 2005  6.736056            6.854917                          5.293075
# ...

# %% [markdown]
# # Come Back

# %%
plt.rcParams.update({'font.size': 40})


def plot_ts_scatter(data):
    time = data.index.get_level_values("Year")
    for key, val in data.items():
        fig, ax = plt.subplots(figsize = (20,12))

        ax.scatter(time, val, alpha = .2, color = 'k', s = 20)
        ax.set_title(key, fontsize = 54)
        mean_data[key].plot(ax = ax, linewidth = 10, color ="C0")
        plt.show()
        plt.savefig(folder + "/" + key + ".jpeg")
        if pp != None:
            pp.savefig(fig, bbox_inches = 'tight')
plot_ts_scatter(data, pp = pp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7l/h6dgk4zj46v592scp_p1cgwr0000gn/T/ipykernel_38567/88212704.py in <module>
#      14         if pp != None:
#      15             pp.savefig(fig, bbox_inches = 'tight')
# ---> 16 plot_ts_scatter(data, pp = pp)
#
# NameError: name 'pp' is not defined

# %%
from matplotlib.backends.backend_pdf import PdfPages
pp = PdfPages(folder + "/ Economic Freedom Plots.pdf")  
# create a pdf


def colo_dim_scatter(data, pp):
    for key1 in data:
        for key2 in data:
        # don't plot the same variable on x and y axis
            if key1 != key2:
                for key3 in data:
                # don't plot the same variable for c, x, and y
                    if key1 != key3 and key2 != key3:
                        fig, ax = plt.subplots(figsize = (20,20))
                        data.plot.scatter(x= key1, 
                                          y = key2, 
                                          c = key3,
                                          colormap = 'viridis',
                                          s = 50,
                                          alpha = .7, 
                                          ax = ax)
                        # remove the ticklines
                        plt.setp(ax.get_xticklines(), visible = False)
                        plt.setp(ax.get_yticklines(), visible = False)
                        # show figure
                        plt.show()
                        # save the figure we showed
                        pp.savefig(fig, bbox_inches = "tight")
                        # close the figure
                        plt.close()

                  
color_dim_scatter(data, pp)
# close the pdf file so that it can be opened
pp.close()
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /var/folders/7l/h6dgk4zj46v592scp_p1cgwr0000gn/T/ipykernel_38567/3059876504.py in <module>
#       1 from matplotlib.backends.backend_pdf import PdfPages
# ----> 2 pp = PdfPages(folder + "/ Economic Freedom Plots.pdf")
#       3 # create a pdf
#       4
#       5
#
# ~/Downloads/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, keep_empty, metadata)
#    2689             and 'CreationDate'. They can be removed by setting them to `None`.
#    2690         """
# -> 2691         self._file = PdfFile(filename, metadata=metadata)
#    2692         self.keep_empty = keep_empty
#    2693
#
# ~/Downloads/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, metadata)
#     652         self.original_file_like = None
# ...

# %%
folder
# Out:
# 'Project 5 Plots'
